# %%
cd
# Out:
# /home/luxx0489

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import sample
import pickle
import mne
from scipy.stats import circmean,circvar
from sklearn import decomposition

# %% [markdown]
# # Section 1 vertical montage from whole scalp

# %%
# first we compare the reference to reveal the difference
# just using PLV and with single channel and all channels

ID_list = [6,7,8,9,10,12,14,16,17,18,19,20,21,22]
Freq_list = [34.28, 91.42]
output = np.empty((len(ID_list)*2*len(Freq_list),5))

# ID, reference(0 for ave, 1 for mastoid), frequency(43.43 and 98),
# Fz, all chan * reference

row_num = 0

for iSubject in ID_list:# range(2,18):

    folder_path = "./jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/"
    sub_id = 'Sub' + str(iSubject) + '_LF'
    raw = mne.io.read_raw_bdf(folder_path + sub_id + '/' + sub_id + '_TMR0_MSK.bdf',
                                   stim_channel='Status', preload=True, exclude = ['EXG3','EXG4','EXG5','EXG6','EXG7','EXG8'])
    events = mne.find_events(raw)

    epochs = mne.Epochs(raw,events=events, tmin=-0.5, tmax=0.5)
    epochs.load_data()
    ep_m = epochs.copy().set_eeg_reference(ref_channels=['EXG1','EXG2'])
    ep_a = epochs.copy().set_eeg_reference(ref_channels='average')
    
    for iRef in range(2):
        if iRef==0:
            data = ep_a.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
        else:
            data = ep_m.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
            

        xw = np.fft.rfft(np.hamming(data.shape[2])*data, axis=2)
        plv = abs((xw/abs(xw)).mean(0))
        plv_mean = plv[0:64,:].mean(0)
        
        freq = np.fft.rfftfreq(data.shape[2],1/4096)
        
        out = xw[:,0:64,:]
        sample_dat = np.concatenate((np.real(out),np.imag(out)),axis=1)
            
        for iFreq in range(len(Freq_list)):
            index = np.argmin(abs(freq-Freq_list[iFreq]))

            output[row_num,0] = iSubject
            output[row_num,1] = iRef
            output[row_num,2] = Freq_list[iFreq]
            output[row_num,3] = plv[37,index]
            output[row_num,4] = plv_mean[index]
            
            row_num +=1

output_L = output
# Out:
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub6_LF/Sub6_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub7_LF/Sub7_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub8_LF/Sub8_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub9_LF/Sub9_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3268607  =      0.000 ...   798.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub10_LF/Sub10_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3297279  =      0.000 ...   805.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub12_LF/Sub12_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3321855  =      0.000 ...   811.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub14_LF/Sub14_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3268607  =      0.000 ...   798.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub16_LF/Sub16_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub17_LF/Sub17_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3313663  =      0.000 ...   809.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub18_LF/Sub18_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3313663  =      0.000 ...   809.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub19_LF/Sub19_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3514367  =      0.000 ...   858.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub20_LF/Sub20_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3547135  =      0.000 ...   866.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub21_LF/Sub21_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3260415  =      0.000 ...   796.000 secs...
# Trigger channel has a non-zero initial value of 65408 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub22_LF/Sub22_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3305471  =      0.000 ...   807.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
# first we compare the reference to reveal the difference
# just using PLV and with single channel and all channels

ID_list = [6,7,8,9,10,12,14,16,17,18,19,20,21,22]
Freq_list = [34.28, 217.13]
output = np.empty((len(ID_list)*2*len(Freq_list),5))

# ID, reference(0 for ave, 1 for mastoid), frequency(43.43 and 98),
# Fz, all chan * reference

row_num = 0

for iSubject in ID_list:# range(2,18):

    folder_path = "./jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/"
    sub_id = 'Sub' + str(iSubject) + '_HF'
    raw = mne.io.read_raw_bdf(folder_path + sub_id + '/' + sub_id + '_TMR0_MSK.bdf',
                                   stim_channel='Status', preload=True, exclude = ['EXG3','EXG4','EXG5','EXG6','EXG7','EXG8'])
    events = mne.find_events(raw)

    epochs = mne.Epochs(raw,events=events, tmin=-0.5, tmax=0.5)
    epochs.load_data()
    ep_m = epochs.copy().set_eeg_reference(ref_channels=['EXG1','EXG2'])
    ep_a = epochs.copy().set_eeg_reference(ref_channels='average')
    
    for iRef in range(2):
        if iRef==0:
            data = ep_a.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
        else:
            data = ep_m.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
            

        xw = np.fft.rfft(np.hamming(data.shape[2])*data, axis=2)
        plv = abs((xw/abs(xw)).mean(0))
        plv_mean = plv[0:64,:].mean(0)
        
        freq = np.fft.rfftfreq(data.shape[2],1/4096)
        
        out = xw[:,0:64,:]
        sample_dat = np.concatenate((np.real(out),np.imag(out)),axis=1)
            
        for iFreq in range(len(Freq_list)):
            index = np.argmin(abs(freq-Freq_list[iFreq]))

            output[row_num,0] = iSubject
            output[row_num,1] = iRef
            output[row_num,2] = Freq_list[iFreq]
            output[row_num,3] = plv[37,index]
            output[row_num,4] = plv_mean[index]
            
            row_num +=1

output_H = output
# Out:
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub6_HF/Sub6_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3272703  =      0.000 ...   799.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub7_HF/Sub7_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3354623  =      0.000 ...   819.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub8_HF/Sub8_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3452927  =      0.000 ...   843.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub9_HF/Sub9_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3305471  =      0.000 ...   807.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub10_HF/Sub10_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3264511  =      0.000 ...   797.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub12_HF/Sub12_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3411967  =      0.000 ...   833.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub14_HF/Sub14_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3248127  =      0.000 ...   793.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub16_HF/Sub16_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3457023  =      0.000 ...   844.000 secs...
# Trigger channel has a non-zero initial value of 65408 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub17_HF/Sub17_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub18_HF/Sub18_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub19_HF/Sub19_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3358719  =      0.000 ...   820.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub20_HF/Sub20_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3338239  =      0.000 ...   815.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub21_HF/Sub21_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3244031  =      0.000 ...   792.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub22_HF/Sub22_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
font = {'weight' : 'regular',
        'size'   : 15}

plt.rc('font', **font)
plt.figure(figsize=(14,8))

Freq_list_H = ['34.28', '217.13']
Freq_list_L = ['34.28', '91.42']

for iSub in range(2):
    plt.subplot(1,2,iSub+1)
    
    if iSub:
        output=output_H
        freq_list = Freq_list_H
    else:
        output=output_L
        freq_list = Freq_list_L

    df = pd.DataFrame(output[:,0:7],columns=['ID','reference','frequency']+ ['Fz','Average'])
    df.head()

    dictionary = {0:'average',1:'linked mastoid'}

    df_f = df.copy().replace({'reference':dictionary})

    df_group = df_f.loc[df_f['reference'] == 'average'].groupby(by = ['frequency'])
    df_avg = df_group.mean()
    df_std = df_group.std()/np.sqrt(len(ID_list))

    wid = 0.5
    chan_list = ['Fz','Average']
    for i in range(2):
        x_tick = [i,i+4]
        plt.bar(x_tick,df_avg[chan_list[i]],yerr = df_std[chan_list[i]], width=wid,
               color = plt.rcParams['axes.prop_cycle'].by_key()['color'][i],
               edgecolor = 'black',
               align='edge',hatch='//')

    df_group = df_f.loc[df_f['reference'] == 'linked mastoid'].groupby(by = ['frequency'])
    df_avg = df_group.mean()
    df_std = df_group.std()/np.sqrt(len(ID_list))

    for i in range(2):
        x_tick = [i+wid,i+wid+4]
        plt.bar(x_tick,df_avg[chan_list[i]],yerr = df_std[chan_list[i]], width=wid,
                           color = plt.rcParams['axes.prop_cycle'].by_key()['color'][i],
               edgecolor = 'black',
               align='edge')
    
    plt.ylim(0,0.15)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('PLV')
    plt.xticks((1,5),labels=freq_list)

# %%
# convert all bdf file to PLV values including extra phases
# this cell is for the low freq session (40Hz + 100Hz)

ID_list = [6,7,8,9,10,12,14,16,17,18,19,20,21,22]

# 34.28 and 91.42 for the tagging frequency and 40 100 Hz for control (noise floor)
Freq_list = [34.28, 91.42, 40,100]
output = np.empty((len(ID_list)*len(Freq_list),8))

# output columns:
# ID, reference(0 for ave, 1 for mastoid), frequency(43.43 and 98),
# linked mastoid plv, horizontal difference plv, vertex plv (Cz + FCz)
# linked mastoid phase, horizontal difference phase, vertex phase (Cz +FCz)

row_num = 0

for iSubject in ID_list:# range(2,18):

    folder_path = "./jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/"
    sub_id = 'Sub' + str(iSubject) + '_LF'
    raw = mne.io.read_raw_bdf(folder_path + sub_id + '/' + sub_id + '_TMR0_MSK.bdf',
                                   stim_channel='Status', preload=True, exclude = ['EXG3','EXG4','EXG5','EXG6','EXG7','EXG8'])
    events = mne.find_events(raw)

    epochs = mne.Epochs(raw,events=events, tmin=-0.5, tmax=0.5)
    epochs.load_data()
    ep_a = epochs.copy().set_eeg_reference(ref_channels='average')
    

    data = ep_a.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]

            
    linked_mastoid = data[:,64:66,:].mean(1)
    diff_horizontal = data[:,64,:] - data[:,65,:]
    vertex_channel = data[:,47,:] + data[:,46,:]
    refs = np.dstack((linked_mastoid,diff_horizontal,vertex_channel)).transpose(0,2,1)
    xw = np.fft.rfft(np.hamming(data.shape[2])*refs, axis=2)
    plv = abs((xw/abs(xw)).mean(0))
    phase = np.angle((xw/abs(xw)).mean(0))

    freq = np.fft.rfftfreq(data.shape[2],1/4096)

    for iFreq in range(len(Freq_list)):
        index = np.argmin(abs(freq-Freq_list[iFreq]))

        output[row_num,0] = iSubject
        output[row_num,1] = Freq_list[iFreq]
        output[row_num,2:5] = plv[:,index]
        output[row_num,5:8] = phase[:,index]

        row_num +=1

output_L = output
# Out:
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub6_LF/Sub6_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub7_LF/Sub7_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub8_LF/Sub8_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub9_LF/Sub9_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3268607  =      0.000 ...   798.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub10_LF/Sub10_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3297279  =      0.000 ...   805.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub12_LF/Sub12_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3321855  =      0.000 ...   811.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub14_LF/Sub14_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3268607  =      0.000 ...   798.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub16_LF/Sub16_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub17_LF/Sub17_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3313663  =      0.000 ...   809.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub18_LF/Sub18_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3313663  =      0.000 ...   809.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub19_LF/Sub19_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3514367  =      0.000 ...   858.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub20_LF/Sub20_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3547135  =      0.000 ...   866.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub21_LF/Sub21_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3260415  =      0.000 ...   796.000 secs...
# Trigger channel has a non-zero initial value of 65408 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub22_LF/Sub22_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3305471  =      0.000 ...   807.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
# same as last chunk but on a different session with tagging frequency at 40 and 200 Hz session

ID_list = [6,7,8,9,10,12,14,16,17,18,19,20,21,22]
Freq_list = [34.28, 217.13,40, 200]

output = np.empty((len(ID_list)*len(Freq_list),8))
# ID, reference(0 for ave, 1 for mastoid), frequency(43.43 and 98), PLV*66 (64 channels+mastoid)


row_num = 0

for iSubject in ID_list:

    folder_path = "./jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/"
    sub_id = 'Sub' + str(iSubject) + '_HF'
    raw = mne.io.read_raw_bdf(folder_path + sub_id + '/' + sub_id + '_TMR0_MSK.bdf',
                                   stim_channel='Status', preload=True, exclude = ['EXG3','EXG4','EXG5','EXG6','EXG7','EXG8'])
    events = mne.find_events(raw)

    epochs = mne.Epochs(raw,events=events, tmin=-0.5, tmax=0.5)
    epochs.load_data()
    ep_a = epochs.copy().set_eeg_reference(ref_channels='average')
    

    data = ep_a.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]

            
    linked_mastoid = data[:,64:66,:].mean(1)
    diff_horizontal = data[:,64,:] - data[:,65,:]
    vertex_channel = (data[:,47,:] + data[:,46,:])/2
    refs = np.dstack((linked_mastoid,diff_horizontal,vertex_channel)).transpose(0,2,1)
    xw = np.fft.rfft(np.hamming(data.shape[2])*refs, axis=2)
    plv = abs((xw/abs(xw)).mean(0))
    phase = np.angle((xw/abs(xw)).mean(0))

    freq = np.fft.rfftfreq(data.shape[2],1/4096)

    for iFreq in range(len(Freq_list)):
        index = np.argmin(abs(freq-Freq_list[iFreq]))

        output[row_num,0] = iSubject
        output[row_num,1] = Freq_list[iFreq]
        output[row_num,2:5] = plv[:,index]
        output[row_num,5:8] = phase[:,index]

        row_num +=1

output_H = output
# Out:
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub6_HF/Sub6_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3272703  =      0.000 ...   799.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub7_HF/Sub7_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3354623  =      0.000 ...   819.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub8_HF/Sub8_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3452927  =      0.000 ...   843.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub9_HF/Sub9_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3305471  =      0.000 ...   807.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub10_HF/Sub10_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3264511  =      0.000 ...   797.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub12_HF/Sub12_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3411967  =      0.000 ...   833.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub14_HF/Sub14_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3248127  =      0.000 ...   793.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub16_HF/Sub16_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3457023  =      0.000 ...   844.000 secs...
# Trigger channel has a non-zero initial value of 65408 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub17_HF/Sub17_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub18_HF/Sub18_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub19_HF/Sub19_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3358719  =      0.000 ...   820.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub20_HF/Sub20_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3338239  =      0.000 ...   815.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub21_HF/Sub21_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3244031  =      0.000 ...   792.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub22_HF/Sub22_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
font = {'weight' : 'regular',
        'size'   : 13}

plt.rc('font', **font)

fig, axes = plt.subplots(1,2,figsize=(14,8))

Freq_set = {34.28, 91.42}

output = output_L

label = [output[iE,1] in Freq_set for iE in range(output.shape[0])]
df = pd.DataFrame(output[label,0:5],columns=['ID','frequency(Hz)']+ ['M1+M2','M1-M2','Cz+FCz'])
df.head()

df_f = df
df_group = df_f.groupby(by=['frequency(Hz)'])
df_avg = df_group.mean()
df_std = df_group.std()/np.sqrt(len(ID_list))
df_avg.drop(columns='ID')
p = df_avg[['M1+M2','Cz+FCz','M1-M2']].plot(kind='bar',yerr=df_std,title='Low-frequency Session',ylim=(0,0.16),
                                           ax = axes[0])
Freq_set = {34.28, 217.13}

output = output_H

label = [output[iE,1] in Freq_set for iE in range(output.shape[0])]

df = pd.DataFrame(output[label,0:5],columns=['ID','frequency(Hz)']+ ['M1+M2','M1-M2','Cz+FCz'])
df.head()

df_f = df
df_group = df_f.groupby(by=['frequency(Hz)'])
df_avg = df_group.mean()
df_std = df_group.std()/np.sqrt(len(ID_list))
df_avg.drop(columns='ID')
p = df_avg[['M1+M2','Cz+FCz','M1-M2']].plot(kind='bar',yerr=df_std,title='High-frequency Session',ylim=(0,0.16),
                                           ax = axes[1])
axes[0].set_ylabel("PLV")
axes[1].set_ylabel("PLV")
# Out:
# Text(0, 0.5, 'PLV')

# %%
plt.figure(figsize=(14,8))

Freq_list = [34.28, 91.42]

output = output_L

ind = output[:,1] == Freq_list[0]
y1 = circmean(output[ind,5]-output[ind,7],np.pi*2,0)
e1 = circvar(output[ind,5]-output[ind,7],np.pi*2,0)
ind = output[:,1] == Freq_list[1]
y2 = circmean(output[ind,5]-output[ind,7],np.pi*2,0)
e2 = circvar(output[ind,5]-output[ind,7],np.pi*2,0)

plt.subplot(1,2,1)
plt.bar([2,5],[y1,y2],yerr=[e1,e2])
plt.xticks([2,5],[str(iE) for iE in Freq_list])
plt.yticks([np.pi/2,np.pi,np.pi/2*3],['pi/2','pi','3pi/2'])
plt.xlabel('Frequency(Hz)')
plt.ylabel('Phase Delay')
plt.axhline(y=np.pi,color='k',alpha=0.5)
plt.xlim(0,7)
plt.title('Low-frequency Session')



Freq_list = [34.28, 217.13]

output = output_H

ind = output[:,1] == Freq_list[0]
y1 = circmean(output[ind,5]-output[ind,7],np.pi*2,0)
e1 = circvar(output[ind,5]-output[ind,7],np.pi*2,0)
ind = output[:,1] == Freq_list[1]
y2 = circmean(output[ind,5]-output[ind,7],np.pi*2,0)
e2 = circvar(output[ind,5]-output[ind,7],np.pi*2,0)


plt.subplot(1,2,2)
plt.bar([2,5],[y1,y2],yerr=[e1,e2])
plt.xticks([2,5],[str(iE) for iE in Freq_list])
plt.yticks([np.pi/2,np.pi,np.pi/2*3],['pi/2','pi','3pi/2'])
plt.xlabel('Frequency(Hz)')
plt.ylabel('Phase Delay')
plt.axhline(y=np.pi,color='k',alpha=0.5)
plt.xlim(0,7)
plt.title('High-frequency Session')
# Out:
# Text(0.5, 1.0, 'High-frequency Session')

# %% [markdown]
# # Section 2. compare multichannel recording methods

# %%
# define functions (requires freq variable)

def ztransform(val, noise):
    return (val-noise.mean())/noise.std()

Target_list = [[34.28,43.43],[91.42,98.28]]
Noise_range_list = [[30,45],[85,100]]
Noise_index = []
for iFreq in range(2):
    index1 = np.argmin(abs(freq-Target_list[iFreq][0]))
    index2 = np.argmin(abs(freq-Target_list[iFreq][1]))
    Noise_range = np.arange(np.argmin(abs(freq-Noise_range_list[iFreq][0])),np.argmin(abs(freq-Noise_range_list[iFreq][1])))
    key1 = np.argwhere(Noise_range==index1)
    key2 = np.argwhere(Noise_range==index2)
    
    Noise_index.append(np.delete(Noise_range,[key1,key2]))

# %%
ID_list = [6,7,8,9,10,12,14,16,17,18,19,20,21,22]
Freq_list = [34.28, 91.42]
sample_size = [200,400,600,800,1000]
output = np.empty((len(ID_list)*2*len(Freq_list)*len(sample_size),12))

# ID, reference(0 for ave, 1 for mastoid), frequency(43.43 and 98),
# all chan plv, 
# all chan ITC,
# all chan T2,
# tPCA, cPCA

row_num = 0

for iSubject in ID_list:

    folder_path = "./jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/"
    sub_id = 'Sub' + str(iSubject) + '_LF'
    raw = mne.io.read_raw_bdf(folder_path + sub_id + '/' + sub_id + '_TMR0_MSK.bdf',
                                   stim_channel='Status', preload=True, exclude = ['EXG3','EXG4','EXG5','EXG6','EXG7','EXG8'])
    events = mne.find_events(raw)

    epochs = mne.Epochs(raw,events=events, tmin=-0.5, tmax=0.5)
    epochs.load_data()
    ep_m = epochs.copy().set_eeg_reference(ref_channels=['EXG1','EXG2'])
    ep_a = epochs.copy().set_eeg_reference(ref_channels='average')
    
    for iRef in range(2):
        if iRef==0:
            data = ep_a.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
        else:
            data = ep_m.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
            
        freq = np.fft.rfftfreq(data.shape[2],1/4096)
        xw_all = np.fft.rfft(np.hamming(data.shape[2])*data, axis=2)
        
        for iSize in range(len(sample_size)):
            
            ind_sample = sample(range(1000),sample_size[iSize])
            xw=xw_all[ind_sample,:,:]
            
            plv = abs((xw/abs(xw)).mean(0))
            itc = abs(xw.mean(0))/(abs(xw).mean(0))

            plv_mean = plv[0:64,:].mean(0)
            itc_mean = itc[0:64,:].mean(0)

            out = xw[:,0:64,:]
            sample_dat = np.concatenate((np.real(out),np.imag(out)),axis=1)

            T2 = np.zeros(sample_dat.shape[2])

            for iFreq in range(5,sample_dat.shape[2]-3):
                batch = sample_dat[:,:,iFreq].transpose(1,0)
                S_inv = np.linalg.inv(np.cov(batch))
                T2[iFreq]=batch.mean(1) @S_inv @batch.mean(1)
                
            #cPCA and MMSC
            plv_mat=np.empty((64,xw.shape[2]))
            msmc = np.empty(xw.shape[2])
            v_mat = []
            for iFreq in range(xw.shape[2]):
                csd = np.matmul(xw[:,0:64,iFreq].T,xw[:,0:64,iFreq].conj())
                w,v = np.linalg.eig(csd)
                v_mat.append(v)
                pc = np.matmul(v.conj().T,xw[:,0:64,iFreq].T)
                cplv = (pc/abs(pc)).mean(1)
                plv_mat[:,iFreq] = abs(cplv)
                
                # MSMC
                v_m = np.matrix(xw[:,0:64,iFreq].mean(0))
                msmc[iFreq] = np.real((v_m.conj() @ np.linalg.inv(csd) @ v_m.T)[0,0])
            
            # concatenate and tPCA
            mix_long = np.concatenate([data[iTrial,0:64,:] for iTrial in ind_sample], axis=1)

            pca = decomposition.PCA(n_components=1)
            pca.fit(mix_long.T)
            pc_t = np.empty((sample_size[iSize],data.shape[2]))
            for iTrial in range(len(ind_sample)):
                pc_t[iTrial,:] = pca.transform(data[ind_sample[iTrial],0:64,:].T).squeeze()
            xw_pc_t = np.fft.rfft(pc_t, axis=1)
            xw_pc_t = xw_pc_t/abs(xw_pc_t)
            plv_pc_t = abs(xw_pc_t.mean(0))
            
            for iFreq in range(len(Freq_list)):
                index = np.argmin(abs(freq-Freq_list[iFreq]))

                output[row_num,0] = iSubject
                output[row_num,1] = iRef
                output[row_num,2] = Freq_list[iFreq]
                output[row_num,3] = sample_size[iSize]
                output[row_num,4] = ztransform(plv[37,index],plv[Noise_index[iFreq]])
                output[row_num,5] = ztransform(itc[37,index],itc[Noise_index[iFreq]])
                output[row_num,6] = ztransform(plv_mean[index],plv_mean[Noise_index[iFreq]])
                output[row_num,7] = ztransform(itc_mean[index],itc_mean[Noise_index[iFreq]])
                output[row_num,8] = ztransform(T2[index],T2[Noise_index[iFreq]])
                output[row_num,9] = ztransform(plv_mat[0,index],plv_mat[0,Noise_index[iFreq]])
                output[row_num,10] = ztransform(plv_pc_t[index],plv_pc_t[Noise_index[iFreq]])
                output[row_num,11] = ztransform(msmc[index], msmc[Noise_index[iFreq]])
                
                row_num +=1
                
file_handle = open(folder_path + '/method_comparison_LF.obj','wb')
pickle.dump(output, file_handle)
file_handle.close()
# Out:
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub6_LF/Sub6_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub7_LF/Sub7_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub8_LF/Sub8_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub9_LF/Sub9_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3268607  =      0.000 ...   798.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub10_LF/Sub10_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3297279  =      0.000 ...   805.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub12_LF/Sub12_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3321855  =      0.000 ...   811.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub14_LF/Sub14_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3268607  =      0.000 ...   798.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub16_LF/Sub16_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3284991  =      0.000 ...   802.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub17_LF/Sub17_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3313663  =      0.000 ...   809.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub18_LF/Sub18_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3313663  =      0.000 ...   809.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub19_LF/Sub19_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3514367  =      0.000 ...   858.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub20_LF/Sub20_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3547135  =      0.000 ...   866.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub21_LF/Sub21_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3260415  =      0.000 ...   796.000 secs...
# Trigger channel has a non-zero initial value of 65408 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/Sub22_LF/Sub22_LF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3305471  =      0.000 ...   807.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
    

ID_list = [6,7,8,9,10,12,14,16,17,18,19,20,21,22]
Freq_list = [34.28, 217.13]
sample_size = [200,400,600,800,1000]
output = np.empty((len(ID_list)*2*len(Freq_list)*len(sample_size),12))


# ID, reference(0 for ave, 1 for mastoid), frequency(43.43 and 98),
# all chan plv, 
# all chan ITC,
# all chan T2,
# tPCA, cPCA

row_num = 0

for iSubject in ID_list:

    folder_path = "./jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/"
    sub_id = 'Sub' + str(iSubject) + '_HF'
    raw = mne.io.read_raw_bdf(folder_path + sub_id + '/' + sub_id + '_TMR0_MSK.bdf',
                                   stim_channel='Status', preload=True, exclude = ['EXG3','EXG4','EXG5','EXG6','EXG7','EXG8'])
    events = mne.find_events(raw)

    epochs = mne.Epochs(raw,events=events, tmin=-0.5, tmax=0.5)
    epochs.load_data()
    ep_m = epochs.copy().set_eeg_reference(ref_channels=['EXG1','EXG2'])
    ep_a = epochs.copy().set_eeg_reference(ref_channels='average')
    
    for iRef in range(2):
        if iRef==0:
            data = ep_a.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
        else:
            data = ep_m.get_data()[:,:,int(np.round((0.5)*4096)):int(np.round((0.5+0.43752)*4096))]
            
        freq = np.fft.rfftfreq(data.shape[2],1/4096)
        xw_all = np.fft.rfft(np.hamming(data.shape[2])*data, axis=2)
        
        for iSize in range(len(sample_size)):
            
            ind_sample = sample(range(1000),sample_size[iSize])
            xw=xw_all[ind_sample,:,:]
            
            plv = abs((xw/abs(xw)).mean(0))
            itc = abs(xw.mean(0))/(abs(xw).mean(0))

            plv_mean = plv[0:64,:].mean(0)
            itc_mean = itc[0:64,:].mean(0)

            out = xw[:,0:64,:]
            sample_dat = np.concatenate((np.real(out),np.imag(out)),axis=1)

            T2 = np.zeros(sample_dat.shape[2])

            for iFreq in range(5,sample_dat.shape[2]-3):
                batch = sample_dat[:,:,iFreq].transpose(1,0)
                S_inv = np.linalg.inv(np.cov(batch))
                T2[iFreq]=batch.mean(1) @S_inv @batch.mean(1)
                
            #cPCA and MMSC
            plv_mat=np.empty((64,xw.shape[2]))
            msmc = np.empty(xw.shape[2])
            v_mat = []
            for iFreq in range(xw.shape[2]):
                csd = np.matmul(xw[:,0:64,iFreq].T,xw[:,0:64,iFreq].conj())
                w,v = np.linalg.eig(csd)
                v_mat.append(v)
                pc = np.matmul(v.conj().T,xw[:,0:64,iFreq].T)
                cplv = (pc/abs(pc)).mean(1)
                plv_mat[:,iFreq] = abs(cplv)
                
                # MSMC
                v_m = np.matrix(xw[:,0:64,iFreq].mean(0))
                msmc[iFreq] = np.real((v_m.conj() @ np.linalg.inv(csd) @ v_m.T)[0,0])
            
            # concatenate and tPCA
            mix_long = np.concatenate([data[iTrial,0:64,:] for iTrial in ind_sample], axis=1)

            pca = decomposition.PCA(n_components=1)
            pca.fit(mix_long.T)
            pc_t = np.empty((sample_size[iSize],data.shape[2]))
            for iTrial in range(len(ind_sample)):
                pc_t[iTrial,:] = pca.transform(data[ind_sample[iTrial],0:64,:].T).squeeze()
            xw_pc_t = np.fft.rfft(pc_t, axis=1)
            xw_pc_t = xw_pc_t/abs(xw_pc_t)
            plv_pc_t = abs(xw_pc_t.mean(0))
            
            for iFreq in range(len(Freq_list)):
                index = np.argmin(abs(freq-Freq_list[iFreq]))

                output[row_num,0] = iSubject
                output[row_num,1] = iRef
                output[row_num,2] = Freq_list[iFreq]
                output[row_num,3] = sample_size[iSize]
                output[row_num,4] = ztransform(plv[37,index],plv[Noise_index[iFreq]])
                output[row_num,5] = ztransform(itc[37,index],itc[Noise_index[iFreq]])
                output[row_num,6] = ztransform(plv_mean[index],plv_mean[Noise_index[iFreq]])
                output[row_num,7] = ztransform(itc_mean[index],itc_mean[Noise_index[iFreq]])
                output[row_num,8] = ztransform(T2[index],T2[Noise_index[iFreq]])
                output[row_num,9] = ztransform(plv_mat[0,index],plv_mat[0,Noise_index[iFreq]])
                output[row_num,10] = ztransform(plv_pc_t[index],plv_pc_t[Noise_index[iFreq]])
                output[row_num,11] = ztransform(msmc[index], msmc[Noise_index[iFreq]])
                
                row_num +=1
                
file_handle = open(folder_path + '/method_comparison_HF.obj','wb')
pickle.dump(output, file_handle)
file_handle.close()
# Out:
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub6_HF/Sub6_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3272703  =      0.000 ...   799.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub7_HF/Sub7_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3354623  =      0.000 ...   819.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub8_HF/Sub8_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3452927  =      0.000 ...   843.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub9_HF/Sub9_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3305471  =      0.000 ...   807.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub10_HF/Sub10_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3264511  =      0.000 ...   797.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub12_HF/Sub12_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3411967  =      0.000 ...   833.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub14_HF/Sub14_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3248127  =      0.000 ...   793.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub16_HF/Sub16_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3457023  =      0.000 ...   844.000 secs...
# Trigger channel has a non-zero initial value of 65408 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub17_HF/Sub17_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub18_HF/Sub18_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub19_HF/Sub19_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3358719  =      0.000 ...   820.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub20_HF/Sub20_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3338239  =      0.000 ...   815.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub21_HF/Sub21_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3244031  =      0.000 ...   792.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /home/luxx0489/jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_HF/Sub22_HF/Sub22_HF_TMR0_MSK.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3289087  =      0.000 ...   803.000 secs...
# Trigger channel has a non-zero initial value of 130944 (consider using initial_event=True to detect this event)
# 1000 events found
# Event IDs: [65409 65410]
# 1000 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 1000 events and 4097 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
folder_path = "./jupyter_projects/MultiChannelSSSR/EEG_data_40_100_200Hz_LF/"
file_handle = open(folder_path +'/method_comparison_LF.obj','rb')
output = pickle.load(file_handle)
file_handle.close()

# %%
# preview data
df = pd.DataFrame(output[:,0:12],columns=['ID','reference','frequency','sample size']+ ['PLV','ITC','plv_mean','itc_mean','T2','cpca','tpca','msmc'])

dictionary = {0:'average',1:'linked mastoid'}

#df_f = df.copy()[df['frequency']== 34.28].replace({'reference':dictionary})
df_f = df.copy()[df['frequency']== 91.42].replace({'reference':dictionary})

df_group = df_f.groupby(by=['frequency','reference','sample size'])
df_avg = df_group.mean()
df_std = df_group.std()/np.sqrt(len(ID_list))
df_avg.drop(columns='ID')
print(df_avg)

p = df_avg[['PLV','plv_mean','T2','cpca','tpca','msmc']].plot(kind='bar',yerr=df_std,figsize = (18,18),fontsize=16,title='Exp 1')

plt.axhline(y=2.58,color='k',alpha=0.5,linestyle='--')
# Out:
#                                              ID       PLV       ITC  plv_mean  \
# frequency reference      sample size
# 91.42     average        200.0        14.214286  2.091669  2.278340  2.300407
#                          400.0        14.214286  2.476479  2.196303  2.830130
#                          600.0        14.214286  3.289092  3.060163  4.071675
#                          800.0        14.214286  3.637751  3.349439  3.528549
#                          1000.0       14.214286  4.004713  3.647976  4.090821
#           linked mastoid 200.0        14.214286  1.421200  1.940267  2.340126
#                          400.0        14.214286  2.963337  2.744371  2.627720
#                          600.0        14.214286  4.026238  3.746643  4.295230
#                          800.0        14.214286  4.172850  3.846655  4.154410
#                          1000.0       14.214286  4.830720  4.569492  5.014317
#
#                                       itc_mean        T2      cpca      tpca  \
# frequency reference      sample size
# 91.42     average        200.0        1.582887  2.465930  0.577017  0.830601
#                          400.0        1.687979  4.378306  0.480314  0.631709
#                          600.0        2.671847  6.258407  0.518302  1.228807
#                          800.0        2.523296  6.481126 -0.259488  1.619985
#                          1000.0       2.796526  7.033156  0.044126  2.021575
#           linked mastoid 200.0        2.056057  3.439127  1.432856  2.136928
#                          400.0        2.491285  4.883195  2.002874  1.817781
#                          600.0        3.812187  7.710973  3.689259  4.164964
#                          800.0        2.837677  6.481901  3.635159  4.027482
#                          1000.0       4.236295  7.033156  3.775147  4.915530
#
#                                           msmc
# frequency reference      sample size
# 91.42     average        200.0        2.707632
#                          400.0        4.704840
#                          600.0        5.676010
#                          800.0        6.235843
#                          1000.0       6.493046
#           linked mastoid 200.0        2.762742
#                          400.0        4.741021
#                          600.0        5.831493
#                          800.0        5.869275
#                          1000.0       6.493046

# %%
(df['frequency']== 91.42) & (df['reference']==0)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 275    False
# 276    False
# 277    False
# 278    False
# 279    False
# Length: 280, dtype: bool

# %%
dictionary.values()
# Out:
# dict_values(['average', 'linked mastoid'])

# %%
df = pd.DataFrame(output[:,0:12],columns=['ID','reference','frequency','sample size']+ ['PLV','ITC','plv_mean','itc_mean','T2','cpca','tpca','msmc'])

dictionary = {0:'average',1:'linked mastoid'}
plt.figure(figsize=(10,10))
Freq_list = [34.28,91.42]

for iFreq in range(2):
    
    for iRef in range(2):
        
        plt.subplot(2,2,iFreq+iRef*2+1)
        #df_f = df.copy()[df['frequency']== 34.28].replace({'reference':dictionary})
        #df_f = df.copy()[(df['frequency']== 91.42) & (df['reference']==1)].replace({'reference':dictionary})
        df_f = df.copy()[(df['frequency']== Freq_list[iFreq]) & (df['reference']==iRef)].replace({'reference':dictionary})

        df_group = df_f.groupby(by=['frequency','reference','sample size'])
        df_avg = df_group.mean()
        df_std = df_group.std()/np.sqrt(len(ID_list))
        df_avg.drop(columns='ID')

        
        plt.axhline(y=2.58,color='k',alpha=0.5,linestyle='--')

        method_list = ['PLV','plv_mean','tpca','cpca','T2','msmc']
        for i in range(len(method_list)):
            x_tick = np.linspace(200,1000,5)
            plt.errorbar(x_tick+i*5,df_avg[method_list[i]],yerr = df_std[method_list[i]],
                   color = plt.rcParams['axes.prop_cycle'].by_key()['color'][i], label=method_list[i])
            
        plt.title(list(dictionary.values())[iRef] + str(Freq_list[iFreq]))
        plt.ylim(-2,12)
        
plt.legend()

# %%
font = {'weight' : 'regular',
        'size'   : 15}

plt.rc('font', **font)
plt.figure(figsize=(14,8))

Freq_list_H = ['34.28', '217.13']
Freq_list_L = ['34.28', '91.42']

for iSub in range(2):
    plt.subplot(1,2,iSub+1)
    
    if iSub:
        output=output_H
        freq_list = Freq_list_H
    else:
        output=output_L
        freq_list = Freq_list_L

    df = pd.DataFrame(output[:,0:7],columns=['ID','reference','frequency']+ ['Fz','Average'])

    dictionary = {0:'average',1:'linked mastoid'}

    df_f = df.copy().replace({'reference':dictionary})

    df_group = df_f.loc[df_f['reference'] == 'average'].groupby(by = ['frequency'])
    df_avg = df_group.mean()
    df_std = df_group.std()/np.sqrt(len(ID_list))

    wid = 0.5
    chan_list = ['Fz','Average']
    for i in range(2):
        x_tick = [i,i+4]
        plt.bar(x_tick,df_avg[chan_list[i]],yerr = df_std[chan_list[i]], width=wid,
               color = plt.rcParams['axes.prop_cycle'].by_key()['color'][i],
               edgecolor = 'black',
               align='edge',hatch='//')

    df_group = df_f.loc[df_f['reference'] == 'linked mastoid'].groupby(by = ['frequency'])
    df_avg = df_group.mean()
    df_std = df_group.std()/np.sqrt(len(ID_list))

    for i in range(2):
        x_tick = [i+wid,i+wid+4]
        plt.bar(x_tick,df_avg[chan_list[i]],yerr = df_std[chan_list[i]], width=wid,
                           color = plt.rcParams['axes.prop_cycle'].by_key()['color'][i],
               edgecolor = 'black',
               align='edge')
    
    plt.ylim(0,0.15)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('PLV')
    plt.xticks((1,5),labels=freq_list)
