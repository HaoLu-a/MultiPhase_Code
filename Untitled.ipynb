# %%
YA.shape
# Out:
# (10, 101, 2)

# %%
T2
# Out:
# SPM{T2}
#    SPM.z      :  (1x101) test stat field
#    SPM.df     :  (2.0, 9.0)
#    SPM.fwhm   :  9.77583
#    SPM.resels :  (1, 10.22931)

# %%
import os
from matplotlib import pyplot
import spm1d



#(0) Load data:
dataset      = spm1d.data.mv1d.hotellings_paired.Pataky2014cop()
YA,YB        = dataset.get_data()  #A:slow, B:fast
print( dataset )



#(1) Conduct test:
alpha        = 0.05
T2           = spm1d.stats.hotellings_paired(YA, YB)
T2i          = T2.inference(0.05)



#(2) Plot:
pyplot.close('all')
ax0     = pyplot.subplot(221)
ax1     = pyplot.subplot(222)
ax3     = pyplot.subplot(224)
## plot SPM results:
ax0.plot(YA[:,:,0].T, 'k', label='slow')
ax0.plot(YB[:,:,0].T, 'r', label='fast')
ax1.plot(YA[:,:,1].T, 'k')
ax1.plot(YB[:,:,1].T, 'r')
T2i.plot(ax=ax3)
# pyplot.show()
# Out:
# Dataset
#    Name      : "Pataky2014cop"
#    Design    :  Paired Hotelling's T2 test
#    Data dim  :  1
#    Reference :  Pataky, T. C., Robinson, M. A., Vanrenterghem, J., Savage, R., Bates, K. T., & Crompton, R. H. (2014). Vector field statistics for objective center-of-pressure trajectory analysis during gait, with evidence of scalar sensitivity to small coordinate system rotations. Gait and Posture, 1–4. http://doi.org/10.1016/j.gaitpost.2014.01.023
#    Data file :  /home/luxx0489/.conda/envs/mne/lib/python3.7/site-packages/spm1d/data/datafiles/Pataky2014cop.npz
#   (Expected results)
#   T2         :  None
#   p          :  None
